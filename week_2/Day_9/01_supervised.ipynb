# %% [markdown]
# In this particular file, we are going to learn about the supervised learning and it types:
# the algorithums which are trained on labled dataset are know as supervised learning.
# it predicts for the goal. Example: email Classification,
# and it has 2 types which ar Regression and Classification.

# %%
# implemetation of Linera regression:

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
